# %% [markdown]
# ## Imports

# %%
import hashlib
import pandas as pd

# %%
clean_instagram_data = pd.read_excel('../data/ground_truth/xlsx_data/instagram_sample_data.xlsx')

# %%
clean_instagram_data
# Out:
#                                                 profile  \
# 0     https://viralpitch.co/instagram/daniellachavez...
# 1          https://viralpitch.co/instagram/ralphlauren/
# 2          https://viralpitch.co/instagram/jeffreestar/
# 3           https://viralpitch.co/instagram/maybelline/
# 4          https://viralpitch.co/instagram/jessica.syj/
# ...                                                 ...
# 3833       https://viralpitch.co/instagram/hamed.grzyn/
# 3834        https://viralpitch.co/instagram/nishumattu/
# 3835  https://viralpitch.co/instagram/jaswantsingh41...
# 3836             https://viralpitch.co/instagram/nxsif/
# 3837           https://viralpitch.co/instagram/bing8.6/
#
#              instagramHandle  \
# 0     daniellachavezofficial
# 1                ralphlauren
# 2                jeffreestar
# 3                 maybelline
# 4                jessica.syj
# ...                      ...
# 3833             hamed.grzyn
# 3834              nishumattu
# ...

# %%
df_anonymized = clean_instagram_data.copy()

# %%
df_anonymized['anonymizedInstagramHandle'] = df_anonymized['instagramHandle'].apply(lambda x: hashlib.sha256(x.encode()).hexdigest()[:7])

# %%
#df_anonymized.to_excel('../data/ground_truth/xlsx_data/instagram_sample_data_partial_anonymized.xlsx', index = False)

# %%
new_columns = ['anonymizedInstagramHandle', 'topK', 'domain',
       'topInfluencer', 'biography',
       'externalUrl', 'externalUrlShimmed', 'followersCount', 'followsCount',
       'hasChannel', 'highlightReelCount', 'isBusinessAccount',
       'joinedRecently', 'businessCategoryName', 'private', 'verified',
       'igtvVideoCount', 'relatedProfiles',
       'latestIgtvVideos', 'postsCount', 'latestPosts']

# %%
df_anonymized = df_anonymized[new_columns]

# %%
df_anonymized
# Out:
#      anonymizedInstagramHandle  topK             domain  topInfluencer  \
# 0                      f6d0ae0     1  beauty_and_makeup              1
# 1                      bcfdadd     2  beauty_and_makeup              1
# 2                      ab53e99     3  beauty_and_makeup              1
# 3                      308a9b0     4  beauty_and_makeup              1
# 4                      a3c0920     5  beauty_and_makeup              1
# ...                        ...   ...                ...            ...
# 3833                   f563933     0             travel              0
# 3834                   b2be7aa     0             travel              0
# 3835                   1f621c4     0             travel              0
# 3836                   ba571b6     0             travel              0
# 3837                   73eaf7b     0             travel              0
#
#                                               biography  \
# 0     💌 Advertisingdch@gmail.com\n@FashionNova Ambas...
# ...

# %%
#df_anonymized.to_excel('../data/ground_truth/xlsx_data/instagram_sample_data_anonymized.xlsx', index = False)
